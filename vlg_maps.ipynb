# %%
crd1=[[16.943273632851724, 80.77899986776463],[16.943273632851724, 80.77556664050661],[16.93736197283696, 80.78758293590968],
        [16.92783724100359, 80.80234581311916],[16.924224285604893, 80.80577904037719],[16.901559620959308, 80.82260185394149],
        [16.888747952947373, 80.82706504937693],[16.8621363253406, 80.83187156753816],[16.85162205693446, 80.83461814934456],
        [16.84275018833599, 80.8404546356832],[16.82237617562682, 80.84560447657024],[16.80824452529433, 80.84594779929604],
        [16.794440501477762, 80.84663444474764],[16.788524183935717, 80.84629112202184]]
crd2=[[16.944642363614864, 80.78205420450813],[16.9439302030255, 80.76939805406687],[16.93395967165405, 80.75971982137649],
      [16.916866103200185, 80.75674190362561],[16.903332594672747, 80.75599742418788],[16.892647559564338, 80.74855262981065],
      [16.884811482515904, 80.74631919149749],[16.879824718644965, 80.74036335599573],[16.87263544505398, 80.73974571024169],
      [16.862121760626888, 80.72875938301603],[16.85719326972535, 80.73596916025787],[16.854893263340582, 80.74661216475774],
      [16.850293166656925, 80.75965842833821],[16.834520557518545, 80.78403434187015],[16.828934109991565, 80.79605063727324],
      [16.822032976761665, 80.80841025540212],[16.805600695789035, 80.81733664627296],[16.796397996587537, 80.83106955530505],
      [16.79113911098591, 80.83896597799848],[16.787523542641598, 80.8417125598049],[16.785880079730177, 80.84892233704676]]

# %%
import folium
from branca.element import Figure
f1=folium.FeatureGroup("way1")
f2=folium.FeatureGroup("way2")
fig5=Figure(height=400,width=400)
map5=folium.Map(location=[16.785565956041808, 80.84869438110246],tiles='cartodbpositron',zoom_start=10)
folium.Marker(location=[16.9432736, 80.7789998],popup='Default popup Marker1',tooltip='this is vissannapeta',icon=folium.Icon(color='blue',icon='none')).add_to(map5)
folium.Marker(location=[16.78556595, 80.848694],popup='Default popup Marker1',tooltip='this is nuzvid',icon=folium.Icon(color='blue',icon='none')).add_to(map5)
folium.Marker(location=[16.8775, 80.7414],popup='Default popup Marker1',tooltip='this is kothareddygudem temple',icon=folium.Icon(color='yellow',icon='bell')).add_to(map5)
folium.Marker(location=[16.7911, 80.8226],popup='Default popup Marker1',tooltip=' iit nuzvid',icon=folium.Icon(color='blue',prefix="fa",icon='university')).add_to(map5)
folium.Marker(location=[16.938644, 80.781771],popup='Default popup Marker1',tooltip='vspt govt hospital',icon=folium.Icon(color='blue',prefix="fa",icon='ambulance')).add_to(map5)
line_1=folium.vector_layers.PolyLine(crd1,popup='<b>Path of Vehicle_1</b>',tooltip='way1',color='blue',weight=10).add_to(f1)
line_2=folium.vector_layers.PolyLine(crd2,popup='<b>Path of Vehicle_2</b>',tooltip='way2',color='red',weight=10).add_to(f2)
f1.add_to(map5)
f2.add_to(map5)
folium.LayerControl().add_to(map5)
fig5.add_child(map5)
map5
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: color argument of Icon should be one of: {'lightblue', 'white', 'darkpurple', 'gray', 'lightgray', 'darkred', 'black', 'purple', 'orange', 'blue', 'lightred', 'lightgreen', 'pink', 'darkgreen', 'cadetblue', 'green', 'darkblue', 'beige', 'red'}.
#   if __name__ == '__main__':
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
# ...
